# %%
import os
# List the contents of the uncompressed folder
os.listdir('dataset')
# Out:
# ['artists.dat',
#  'readme.txt',
#  'tags.dat',
#  'user_artists.dat',
#  'user_friends.dat',
#  'user_taggedartists-timestamps.dat',
#  'user_taggedartists.dat']

# %% [markdown]
# # Analisis Exploratorio de Datos
# Esta parte del proyecto consiste en cargar los datasets para poder explorarlos

# %%
import pandas as pd

artists = pd.read_csv('dataset/artists.dat', sep='\t')
artists.head(20)
# Out:
#     id                   name                                             url  \
# 0    1           MALICE MIZER           http://www.last.fm/music/MALICE+MIZER
# 1    2        Diary of Dreams        http://www.last.fm/music/Diary+of+Dreams
# 2    3      Carpathian Forest      http://www.last.fm/music/Carpathian+Forest
# 3    4           Moi dix Mois           http://www.last.fm/music/Moi+dix+Mois
# 4    5            Bella Morte            http://www.last.fm/music/Bella+Morte
# 5    6              Moonspell              http://www.last.fm/music/Moonspell
# 6    7         Marilyn Manson         http://www.last.fm/music/Marilyn+Manson
# 7    8            DIR EN GREY            http://www.last.fm/music/DIR+EN+GREY
# 8    9            Combichrist            http://www.last.fm/music/Combichrist
# 9   10                Grendel                http://www.last.fm/music/Grendel
# 10  11               Agonoize               http://www.last.fm/music/Agonoize
# 11  12               Behemoth               http://www.last.fm/music/Behemoth
# 12  13                 Hocico                 http://www.last.fm/music/Hocico
# 13  15           Dimmu Borgir           http://www.last.fm/music/Dimmu+Borgir
# 14  16  London After Midnight  http://www.last.fm/music/London+After+Midnight
# 15  17           Psyclon Nine           http://www.last.fm/music/Psyclon+Nine
# 16  18        The Crüxshadows   http://www.last.fm/music/The+Cr%C3%BCxshadows
# 17  19             :wumpscut:         http://www.last.fm/music/%3Awumpscut%3A
# 18  20           Limbonic Art           http://www.last.fm/music/Limbonic+Art
# 19  21    Artista sconosciuto    http://www.last.fm/music/Artista+sconosciuto
#
#                                            pictureURL
# 0     http://userserve-ak.last.fm/serve/252/10808.jpg
# 1   http://userserve-ak.last.fm/serve/252/3052066.jpg
# 2   http://userserve-ak.last.fm/serve/252/40222717...
# 3   http://userserve-ak.last.fm/serve/252/54697835...
# 4   http://userserve-ak.last.fm/serve/252/14789013...
# 5   http://userserve-ak.last.fm/serve/252/2181591.jpg
# 6   http://userserve-ak.last.fm/serve/252/2558217.jpg
# 7   http://userserve-ak.last.fm/serve/252/46968835...
# 8   http://userserve-ak.last.fm/serve/252/51273485...
# 9   http://userserve-ak.last.fm/serve/252/5872875.jpg
# 10  http://userserve-ak.last.fm/serve/252/31693309...
# 11  http://userserve-ak.last.fm/serve/252/54196161...
# 12  http://userserve-ak.last.fm/serve/252/34892635...
# 13  http://userserve-ak.last.fm/serve/252/52216127...
# 14  http://userserve-ak.last.fm/serve/252/5364091.jpg
# 15  http://userserve-ak.last.fm/serve/252/35246025...
# 16  http://userserve-ak.last.fm/serve/252/10323129...
# 17   http://userserve-ak.last.fm/serve/252/541326.jpg
# 18  http://userserve-ak.last.fm/serve/252/29314111...
# 19  http://userserve-ak.last.fm/serve/252/17969009...

# %%
tags = pd.read_csv('dataset/tags.dat', sep='\t', encoding='ISO-8859-1')
tags.head(20)
# Out:
#     tagID            tagValue
# 0       1               metal
# 1       2   alternative metal
# 2       3           goth rock
# 3       4         black metal
# 4       5         death metal
# 5       6    industrial metal
# 6       7        gothic metal
# 7       8          terror ebm
# 8       9  electro-industrial
# 9      10           harsh ebm
# 10     11    post black metal
# 11     12           aggrotech
# 12     13            chillout
# 13     14             ambient
# 14     15           downtempo
# 15     16            new wave
# 16     17           synth pop
# 17     18          electronic
# 18     19                80's
# 19     20              lounge

# %%
user_artists = pd.read_csv('dataset/user_artists.dat', sep='\t')
user_artists.head(20)
# Out:
#     userID  artistID  weight
# 0        2        51   13883
# 1        2        52   11690
# 2        2        53   11351
# 3        2        54   10300
# 4        2        55    8983
# 5        2        56    6152
# 6        2        57    5955
# 7        2        58    4616
# 8        2        59    4337
# 9        2        60    4147
# 10       2        61    3923
# 11       2        62    3782
# 12       2        63    3735
# 13       2        64    3644
# 14       2        65    3579
# 15       2        66    3312
# 16       2        67    3301
# 17       2        68    2927
# 18       2        69    2720
# 19       2        70    2686

# %%
user_tags = pd.read_csv('dataset/user_taggedartists.dat', sep='\t')
user_tags.head(20)
# Out:
#     userID  artistID  tagID  day  month  year
# 0        2        52     13    1      4  2009
# 1        2        52     15    1      4  2009
# 2        2        52     18    1      4  2009
# 3        2        52     21    1      4  2009
# 4        2        52     41    1      4  2009
# 5        2        63     13    1      4  2009
# 6        2        63     14    1      4  2009
# 7        2        63     23    1      4  2009
# 8        2        63     40    1      4  2009
# 9        2        73     13    1      4  2009
# 10       2        73     14    1      4  2009
# 11       2        73     15    1      4  2009
# 12       2        73     18    1      4  2009
# 13       2        73     20    1      4  2009
# 14       2        73     21    1      4  2009
# 15       2        73     22    1      4  2009
# 16       2        73     26    1      4  2009
# 17       2        94     13    1      4  2009
# 18       2        94     15    1      4  2009
# 19       2        94     20    1      4  2009

# %% [markdown]
# # Let's generate some plots

# %% [markdown]
# ## Artistas mas populares

# %%
import matplotlib.pyplot as plt
import seaborn as sns

palette = 'CMRmap'
top = 50

# Get total weights per artist
top_artists = user_artists.groupby('artistID')['weight'].sum().reset_index()

# Get only top k artists
top_artists = top_artists.sort_values('weight', ascending=False)

# Join with the artists DataFrame to get artist names
top_artists = top_artists.merge(artists[['id', 'name']], left_on='artistID', right_on='id', how='left')

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(data=top_artists.head(top), x='weight', y='name', palette=palette)


plt.xlabel('Interacciones totales')
plt.ylabel('Artista')
plt.title(f'Top {top} Artistas Más Populares')
# Out:
# /tmp/ipykernel_7164/4076688836.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_artists.head(top), x='weight', y='name', palette=palette)
# Text(0.5, 1.0, 'Top 50 Artistas Más Populares')

# %% [markdown]
# Generos mas populares

# %%
tag_counts = user_tags['tagID'].value_counts().reset_index()
tag_counts.columns = ['tagID', 'count']

# Merge with tags df
tag_counts = tag_counts.merge(tags[['tagID', 'tagValue']], how='left')

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(data=tag_counts.head(top), x='count', y='tagValue', palette=palette)

plt.xlabel('Interacciones totales')
plt.ylabel('Tag')
plt.title(f'Top {top} Tags Más Populares')
# Out:
# /tmp/ipykernel_7164/616108465.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tag_counts.head(top), x='count', y='tagValue', palette=palette)
# Text(0.5, 1.0, 'Top 50 Tags Más Populares')

# %%
# Show how many tags are really unpopular
threshold = 100

unpopular_tags = tag_counts[tag_counts['count'] < threshold]['tagID'].nunique()
print(f'There are {unpopular_tags} tags with less than {threshold} applications. This represents {unpopular_tags * 100 / len(tag_counts)}%')
# Out:
# There are 9522 tags with less than 100 applications. This represents 97.6715560570315%

# %%
# Make a histogram with the tag counts
import math
dropped_tags = tag_counts[tag_counts['count'] >= threshold]

# Plot a histogram
plt.figure(figsize=(12, 8))
sns.histplot(data=dropped_tags, x='count', kde=True)

plt.xlabel('Interacciones totales')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Do the same for artists
artist_threshold = 10000

dropped_artists = top_artists[top_artists['weight'] >= artist_threshold]

# Calculate the number of bins
artist_bins = math.floor(1 + math.log2(len(dropped_artists)))
print(dropped_artists)
# Plot a histogram
plt.figure(figsize=(12, 8))
sns.histplot(data=dropped_artists, x='weight', kde=True)

plt.xlabel('Interacciones totales')
plt.ylabel('Frecuencia')
plt.title(f'Distribucion de reproducciones por artista')
plt.show()
# Out:
#      artistID   weight    id                name
# 0         289  2393140   289      Britney Spears
# 1          72  1301308    72        Depeche Mode
# 2          89  1291387    89           Lady Gaga
# 3         292  1058405   292  Christina Aguilera
# 4         498   963449   498            Paramore
# ..        ...      ...   ...                 ...
# 938      4166    10011  4166             Confide
# 939       999    10010   999      Thompson Twins
# 940      4435    10007  4435         The Bravery
# 941      8071    10007  8071         Ryan Leslie
# 942      4226    10004  4226               7раса
#
# [943 rows x 4 columns]

# %%
user_hours = user_artists.groupby('userID')['weight'].sum().reset_index().sort_values('weight', ascending=False)
user_hours.head(10)

plt.figure(figsize=(12, 8))
sns.boxplot(data=user_hours, y='weight', color='lightcoral')

plt.ylabel('Total Listen Times(Weight)')
plt.title('Distribucion de la cantidad de reproducciones por usuario')

plt.show()

# Now make a histogram for the same dataframe
plt.figure(figsize=(12, 8))
sns.histplot(data=user_hours, x='weight', kde=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>
